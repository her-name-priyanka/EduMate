# %% [markdown]
# # EduMate – AI Agent Notebook
# This notebook demonstrates the EduMate agent pipeline.

# %%
from src.pipeline import EduMatePipeline
bot = EduMatePipeline()
bot.run("Explain AI agents")
